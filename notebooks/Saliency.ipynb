# %% [markdown]
# # Randomized Image Sampling for Explanations (RISE)

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.utils.data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models

from techniques.rise_utils import *
from techniques.explanations import RISE

cudnn.benchmark = True

# %%
args = Dummy()

# Number of workers to load data
args.workers = 8
# Directory with images split into class folders.
# Since we don't use ground truth labels for saliency all images can be 
# moved to one class folder.
args.datadir = 'data/ILSVRC2012_img_val/'
# Sets the range of images to be explained for dataloader.
args.range = range(0, 10)
# Size of imput images.
args.input_size = (224, 224)
# Size of batches for GPU. 
# Use maximum number that the GPU allows.
args.gpu_batch = 250

# %% [markdown]
# ## Prepare data

# %%
#dataset = datasets.ImageFolder(args.datadir, preprocess)

# This example only works with batch size 1. For larger batches see RISEBatch in explanations.py.
data_loader = torch.utils.data.DataLoader(
    args.datadir, batch_size=1, shuffle=False,
    num_workers=args.workers, pin_memory=True, sampler=RangeSampler(args.range))

#print('Found {: >5} images belonging to {} classes.'.format(len(dataset), len(dataset.classes)))
print('      {: >5} images will be explained.'.format(len(data_loader) * data_loader.batch_size))
# Out:
#          10 images will be explained.

# %% [markdown]
# ## Load black-box model

# %%
# Load black box model for explanations
model = models.resnet18(pretrained=True)
model = nn.Sequential(model, nn.Softmax(dim=1))
model = model.eval()
#model = model.cuda()

for p in model.parameters():
    p.requires_grad = False
    
# To use multiple GPUs
#model = nn.DataParallel(model)

# %% [markdown]
# ## Create explainer instance

# %%
explainer = RISE(model, args.input_size, args.gpu_batch)

# %%
# %reload_ext autoreload
# %autoreload 2
# Generate masks for RISE or use the saved ones.
maskspath = 'masks.npy'
generate_new = True

if generate_new or not os.path.isfile(maskspath):
    explainer.generate_masks(N=6000, s=8, p1=0.1, savepath=maskspath)
    print("Masks are generated.")
else:
    explainer.load_masks(maskspath)
    print('Masks are loaded.')
# Out:
# Generating filters: 100%|██████████| 6000/6000 [00:14<00:00, 417.20it/s]
# Masks are generated.

# %%
import cv2
img = cv2.imread('data/ILSVRC2012_img_val/ILSVRC2012_val_00036091.JPEG')
print(np.array(img).shape)
val_img = cv2.resize(img, (224, 224))
plt.imshow(img)
# Out:
# (480, 640, 3)

# %% [markdown]
# ## Explaining one instance
# Producing saliency maps for top $k$ predicted classes.

# %%
gen_rise_grounding(read_tensor('data/ILSVRC2012_img_val/ILSVRC2012_val_00036091.JPEG'), 'resnet18')
# Out:
# Generating filters: 100%|██████████| 6000/6000 [00:14<00:00, 418.04it/s]
# Masks are generated.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-7747a59da7f3> in <module>()
# ----> 1 gen_rise_grounding(val_img, 'resnet18')
#
# /Users/lisadunlap/explain-eval/techniques/rise_utils.py in gen_rise_grounding(img, model_name, cuda)
#     123
#     124     #explain instance
# --> 125     sal = explain_instance(model, explainer, read_tensor('data/ILSVRC2012_img_val/ILSVRC2012_val_00036091.JPEG'), 1)
#     126     return sal
#
# /Users/lisadunlap/anaconda3/lib/python3.6/site-packages/torchvision-0.2.0-py3.6.egg/torchvision/transforms/transforms.py in __call__(self, img)
#      40     def __call__(self, img):
#      41         for t in self.transforms:
# ---> 42             img = t(img)
#      43         return img
#      44
#
# /Users/lisadunlap/explain-eval/techniques/rise_utils.py in <lambda>(x)
#      16 # Function that opens image from disk, normalizes it and converts to tensor
#      17 read_tensor = transforms.Compose([
# ---> 18     lambda x: Image.fromarray(x),
#      19     transforms.Resize((224, 224)),
#      20     transforms.ToTensor(),
#
# /Users/lisadunlap/anaconda3/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2506     .. versionadded:: 1.1.6
#    2507     """
# -> 2508     arr = obj.__array_interface__
#    2509     shape = arr['shape']
#    2510     ndim = len(shape)
#
# AttributeError: 'str' object has no attribute '__array_interface__'

# %%
def example(img, top_k=3):
    saliency = explainer(img).cpu().numpy()
    p, c = torch.topk(model(img), k=top_k)
    p, c = p[0], c[0]
    
    plt.figure(figsize=(10, 5*top_k))
    for k in range(top_k):
        plt.subplot(top_k, 2, 2*k+1)
        plt.axis('off')
        plt.title('{:.2f}% {}'.format(100*p[k], get_class_name(c[k])))
        tensor_imshow(img[0])

        plt.subplot(top_k, 2, 2*k+2)
        plt.axis('off')
        plt.title(get_class_name(c[k]))
        tensor_imshow(img[0])
        sal = saliency[c[k]]
        plt.imshow(sal, cmap='jet', alpha=0.5)
        plt.colorbar(fraction=0.046, pad=0.04)

    plt.show()
    return sal

# %%
sal = example(read_tensor('data/ILSVRC2012_img_val/ILSVRC2012_val_00036091.JPEG'), 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-d6f810e7d903> in <module>()
# ----> 1 sal = example(read_tensor('data/ILSVRC2012_img_val/ILSVRC2012_val_00036091.JPEG'), 1)
#
# /Users/lisadunlap/anaconda3/lib/python3.6/site-packages/torchvision-0.2.0-py3.6.egg/torchvision/transforms/transforms.py in __call__(self, img)
#      40     def __call__(self, img):
#      41         for t in self.transforms:
# ---> 42             img = t(img)
#      43         return img
#      44
#
# /Users/lisadunlap/explain-eval/techniques/rise_utils.py in <lambda>(x)
#      16 # Function that opens image from disk, normalizes it and converts to tensor
#      17 read_tensor = transforms.Compose([
# ---> 18     lambda x: Image.open(x),
#      19     transforms.Resize((224, 224)),
#      20     transforms.ToTensor(),
#
# /Users/lisadunlap/anaconda3/lib/python3.6/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2506     .. versionadded:: 1.1.6
#    2507     """
# -> 2508     arr = obj.__array_interface__
#    2509     shape = arr['shape']
#    2510     ndim = len(shape)
#
# AttributeError: 'str' object has no attribute '__array_interface__'

# %% [markdown]
# ## Explaining all images in dataloader
# Explaining the top predicted class for each image.

# %%
def explain_all(data_loader, explainer):
    # Get all predicted labels first
    target = np.empty(len(data_loader), np.int)
    for i, (img, _) in enumerate(tqdm(data_loader, total=len(data_loader), desc='Predicting labels')):
        p, c = torch.max(model(img.cuda()), dim=1)
        target[i] = c[0]

    # Get saliency maps for all images in val loader
    explanations = np.empty((len(data_loader), *args.input_size))
    for i, (img, _) in enumerate(tqdm(data_loader, total=len(data_loader), desc='Explaining images')):
        saliency_maps = explainer(img.cuda())
        explanations[i] = saliency_maps[target[i]].cpu().numpy()
    return explanations

# %%
explanations = explain_all(data_loader, explainer)

# Save explanations if needed.
# explanations.tofile('exp_{:05}-{:05}.npy'.format(args.range[0], args.range[-1]))
# Out:
# Predicting labels:   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-1621556e3bc0> in <module>()
# ----> 1 explanations = explain_all(data_loader, explainer)
#       2
#       3 # Save explanations if needed.
#       4 # explanations.tofile('exp_{:05}-{:05}.npy'.format(args.range[0], args.range[-1]))
#
# <ipython-input-14-4312bdde6db9> in explain_all(data_loader, explainer)
#       2     # Get all predicted labels first
#       3     target = np.empty(len(data_loader), np.int)
# ----> 4     for i, (img, _) in enumerate(tqdm(data_loader, total=len(data_loader), desc='Predicting labels')):
#       5         p, c = torch.max(model(img.cuda()), dim=1)
#       6         target[i] = c[0]
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
for i, (img, _) in enumerate(data_loader):
    p, c = torch.max(model(img.cuda()), dim=1)
    p, c = p[0].item(), c[0].item()
    
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.axis('off')
    plt.title('{:.2f}% {}'.format(100*p, get_class_name(c)))
    tensor_imshow(img[0])
    
    plt.subplot(122)
    plt.axis('off')
    plt.title(get_class_name(c))
    tensor_imshow(img[0])
    sal = explanations[i]
    plt.imshow(sal, cmap='jet', alpha=0.5)
    #plt.colorbar(fraction=0.046, pad=0.04)
    
    plt.show()
