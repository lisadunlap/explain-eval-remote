# %%
import os
import shutil

# %%
for dirpath, dirnames, filenames in os.walk('/work/lisabdunlap/'):
    for d in dirnames:
        if 'pymp-' in d:
            print(dirpath+'/'+d)
            try:
                #os.rmdir(dirpath+'/'+d)
                shutil.rmtree(dirpath+'/'+d)
            except OSError as ex:
                print(ex)
# Out:
# /work/lisabdunlap/train-tiny-imagenet/pymp-fu9bac2o
# /work/lisabdunlap/train-tiny-imagenet/pymp-6wbun0r3
# /work/lisabdunlap/train-tiny-imagenet/pymp-nba89rlv
# /work/lisabdunlap/train-tiny-imagenet/pymp-c4xznjx7
# /work/lisabdunlap/train-tiny-imagenet/pymp-02lnnr_d
# /work/lisabdunlap/train-tiny-imagenet/pymp-ypoc91hs
# /work/lisabdunlap/train-tiny-imagenet/pymp-08w5wuqw
# /work/lisabdunlap/train-tiny-imagenet/pymp-w5nt1ll9
# /work/lisabdunlap/train-tiny-imagenet/pymp-zeh4qa7r
# /work/lisabdunlap/train-tiny-imagenet/pymp-2fms0ie5
# /work/lisabdunlap/train-tiny-imagenet/pymp-sb_1r5ur
# /work/lisabdunlap/train-tiny-imagenet/pymp-s7x5v358
# /work/lisabdunlap/train-tiny-imagenet/pymp-h706lh_3
# /work/lisabdunlap/train-tiny-imagenet/pymp-78sllb9y
# /work/lisabdunlap/train-tiny-imagenet/pymp-edpryh27
# /work/lisabdunlap/train-tiny-imagenet/pymp-kr6bsi5h
# /work/lisabdunlap/train-tiny-imagenet/pymp-3976p1de
# /work/lisabdunlap/train-tiny-imagenet/pymp-txtevb_6
# ...
