# %% [markdown]
# # Randomized Image Sampling for Explanations (RISE)

# %%
import os
import numpy as np
from matplotlib import pyplot as plt
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.utils.data
import torchvision.transforms as transforms
import torchvision.datasets as datasets
import torchvision.models as models

from rise_2.rise_utils_2 import *
from rise_2.rise_expl import RISE

cudnn.benchmark = True

# %%
args = Dummy()

# Number of workers to load data
args.workers = 8
# Directory with images split into class folders.
# Since we don't use ground truth labels for saliency all images can be 
# moved to one class folder.
args.datadir = '/work/lisabdunlap/explain-eval/data/ILSVRC2012_img_val/'
# Sets the range of images to be explained for dataloader.
args.range = range(0, 10)
# Size of imput images.
args.input_size = (224, 224)
# Size of batches for GPU. 
# Use maximum number that the GPU allows.
args.gpu_batch = 250

# %% [markdown]
# ## Prepare data

# %%
dataset = datasets.ImageFolder(args.datadir, preprocess)

# This example only works with batch size 1. For larger batches see RISEBatch in explanations.py.
data_loader = torch.utils.data.DataLoader(
    dataset, batch_size=1, shuffle=False,
    num_workers=args.workers, pin_memory=True, sampler=RangeSampler(args.range))

print('Found {: >5} images belonging to {} classes.'.format(len(dataset), len(dataset.classes)))
print('      {: >5} images will be explained.'.format(len(data_loader) * data_loader.batch_size))
# Out:
# Found     1 images belonging to 1 classes.
#          10 images will be explained.

# %% [markdown]
# ## Load black-box model

# %%
# Load black box model for explanations
model = models.resnet50(True)
model = nn.Sequential(model, nn.Softmax(dim=1))
model = model.eval()
model = model.cuda()

for p in model.parameters():
    p.requires_grad = False
    
# To use multiple GPUs
# model = nn.DataParallel(model)

# %% [markdown]
# ## Create explainer instance

# %%
explainer = RISE(model, args.input_size, args.gpu_batch)

# %%
# Generate masks for RISE or use the saved ones.
maskspath = 'masks.npy'
generate_new = True

if generate_new or not os.path.isfile(maskspath):
    explainer.generate_masks(N=6000, s=8, p1=0.1, savepath=maskspath)
else:
    explainer.load_masks(maskspath)
    print('Masks are loaded.')
# Out:
# Generating filters:   0%|          | 0/6000 [00:00<?, ?it/s]
# Generating filters:   1%|          | 31/6000 [00:00<00:19, 302.71it/s]
# Generating filters:   1%|          | 63/6000 [00:00<00:19, 306.82it/s]
# Generating filters:   2%|▏         | 97/6000 [00:00<00:18, 315.38it/s]
# Generating filters:   2%|▏         | 131/6000 [00:00<00:18, 321.78it/s]
# Generating filters:   3%|▎         | 165/6000 [00:00<00:17, 325.62it/s]
# Generating filters:   3%|▎         | 199/6000 [00:00<00:17, 329.14it/s]
# Generating filters:   4%|▍         | 233/6000 [00:00<00:17, 331.71it/s]
# Generating filters:   4%|▍         | 268/6000 [00:00<00:17, 334.44it/s]
# Generating filters:   5%|▌         | 303/6000 [00:00<00:16, 336.97it/s]
# Generating filters:   6%|▌         | 339/6000 [00:01<00:16, 342.65it/s]
# Generating filters:   6%|▋         | 375/6000 [00:01<00:16, 346.04it/s]
# Generating filters:   7%|▋         | 411/6000 [00:01<00:15, 349.87it/s]
# Generating filters:   7%|▋         | 447/6000 [00:01<00:15, 352.71it/s]
# Generating filters:   8%|▊         | 483/6000 [00:01<00:15, 354.56it/s]
# Generating filters:   9%|▊         | 519/6000 [00:01<00:15, 355.99it/s]
# Generating filters:   9%|▉         | 555/6000 [00:01<00:15, 354.06it/s]
# Generating filters:  10%|▉         | 591/6000 [00:01<00:15, 355.55it/s]
# Generating filters:  10%|█         | 627/6000 [00:01<00:15, 353.74it/s]
# Generating filters:  11%|█         | 663/6000 [00:01<00:15, 348.78it/s]
# Generating filters:  12%|█▏        | 698/6000 [00:02<00:15, 344.78it/s]
# Generating filters:  12%|█▏        | 733/6000 [00:02<00:15, 342.56it/s]
# Generating filters:  13%|█▎        | 768/6000 [00:02<00:15, 340.75it/s]
# Generating filters:  13%|█▎        | 803/6000 [00:02<00:15, 339.41it/s]
# Generating filters:  14%|█▍        | 837/6000 [00:02<00:15, 339.51it/s]
# Generating filters:  15%|█▍        | 871/6000 [00:02<00:15, 336.95it/s]
# Generating filters:  15%|█▌        | 906/6000 [00:02<00:14, 339.82it/s]
# Generating filters:  16%|█▌        | 941/6000 [00:02<00:14, 341.42it/s]
# Generating filters:  16%|█▋        | 976/6000 [00:02<00:14, 343.76it/s]
# Generating filters:  17%|█▋        | 1013/6000 [00:02<00:14, 348.34it/s]
# Generating filters:  18%|█▊        | 1050/6000 [00:03<00:14, 353.27it/s]
# Generating filters:  18%|█▊        | 1087/6000 [00:03<00:13, 357.20it/s]
# Generating filters:  19%|█▊        | 1123/6000 [00:03<00:13, 357.77it/s]
# Generating filters:  19%|█▉        | 1159/6000 [00:03<00:13, 354.01it/s]
# Generating filters:  20%|█▉        | 1195/6000 [00:03<00:13, 349.97it/s]
# Generating filters:  21%|██        | 1231/6000 [00:03<00:13, 347.65it/s]
# Generating filters:  21%|██        | 1267/6000 [00:03<00:13, 349.78it/s]
# Generating filters:  22%|██▏       | 1304/6000 [00:03<00:13, 352.98it/s]
# Generating filters:  22%|██▏       | 1340/6000 [00:03<00:13, 352.66it/s]
# Generating filters:  23%|██▎       | 1376/6000 [00:03<00:13, 350.03it/s]
# Generating filters:  24%|██▎       | 1412/6000 [00:04<00:13, 348.62it/s]
# Generating filters:  24%|██▍       | 1447/6000 [00:04<00:13, 347.54it/s]
# Generating filters:  25%|██▍       | 1482/6000 [00:04<00:13, 346.44it/s]
# Generating filters:  25%|██▌       | 1517/6000 [00:04<00:12, 345.91it/s]
# Generating filters:  26%|██▌       | 1552/6000 [00:04<00:12, 346.25it/s]
# Generating filters:  26%|██▋       | 1587/6000 [00:04<00:12, 346.29it/s]
# Generating filters:  27%|██▋       | 1622/6000 [00:04<00:12, 345.02it/s]
# Generating filters:  28%|██▊       | 1657/6000 [00:04<00:12, 345.17it/s]
# Generating filters:  28%|██▊       | 1692/6000 [00:04<00:12, 343.38it/s]
# Generating filters:  29%|██▉       | 1727/6000 [00:05<00:12, 342.44it/s]
# Generating filters:  29%|██▉       | 1762/6000 [00:05<00:12, 342.30it/s]
# Generating filters:  30%|██▉       | 1797/6000 [00:05<00:12, 342.16it/s]
# Generating filters:  31%|███       | 1832/6000 [00:05<00:12, 342.89it/s]
# Generating filters:  31%|███       | 1867/6000 [00:05<00:12, 343.86it/s]
# Generating filters:  32%|███▏      | 1902/6000 [00:05<00:11, 345.23it/s]
# Generating filters:  32%|███▏      | 1937/6000 [00:05<00:11, 346.42it/s]
# Generating filters:  33%|███▎      | 1974/6000 [00:05<00:11, 350.97it/s]
# Generating filters:  34%|███▎      | 2010/6000 [00:05<00:11, 351.56it/s]
# Generating filters:  34%|███▍      | 2046/6000 [00:05<00:11, 352.78it/s]
# Generating filters:  35%|███▍      | 2083/6000 [00:06<00:11, 355.23it/s]
# Generating filters:  35%|███▌      | 2120/6000 [00:06<00:10, 356.82it/s]
# Generating filters:  36%|███▌      | 2156/6000 [00:06<00:10, 353.97it/s]
# Generating filters:  37%|███▋      | 2192/6000 [00:06<00:10, 350.23it/s]
# Generating filters:  37%|███▋      | 2228/6000 [00:06<00:10, 346.33it/s]
# Generating filters:  38%|███▊      | 2263/6000 [00:06<00:10, 343.39it/s]
# Generating filters:  38%|███▊      | 2298/6000 [00:06<00:10, 341.37it/s]
# Generating filters:  39%|███▉      | 2333/6000 [00:06<00:10, 340.22it/s]
# Generating filters:  39%|███▉      | 2368/6000 [00:06<00:10, 338.81it/s]
# Generating filters:  40%|████      | 2402/6000 [00:06<00:10, 333.54it/s]
# Generating filters:  41%|████      | 2436/6000 [00:07<00:10, 334.01it/s]
# Generating filters:  41%|████      | 2470/6000 [00:07<00:10, 334.21it/s]
# Generating filters:  42%|████▏     | 2504/6000 [00:07<00:10, 335.24it/s]
# Generating filters:  42%|████▏     | 2539/6000 [00:07<00:10, 337.36it/s]
# Generating filters:  43%|████▎     | 2574/6000 [00:07<00:10, 339.95it/s]
# Generating filters:  44%|████▎     | 2610/6000 [00:07<00:09, 343.67it/s]
# Generating filters:  44%|████▍     | 2646/6000 [00:07<00:09, 347.19it/s]
# Generating filters:  45%|████▍     | 2682/6000 [00:07<00:09, 348.72it/s]
# Generating filters:  45%|████▌     | 2717/6000 [00:07<00:09, 347.74it/s]
# Generating filters:  46%|████▌     | 2752/6000 [00:07<00:09, 345.99it/s]
# Generating filters:  46%|████▋     | 2787/6000 [00:08<00:09, 342.28it/s]
# Generating filters:  47%|████▋     | 2822/6000 [00:08<00:09, 340.20it/s]
# Generating filters:  48%|████▊     | 2857/6000 [00:08<00:09, 340.42it/s]
# Generating filters:  48%|████▊     | 2892/6000 [00:08<00:09, 341.21it/s]
# Generating filters:  49%|████▉     | 2927/6000 [00:08<00:09, 340.62it/s]
# Generating filters:  49%|████▉     | 2962/6000 [00:08<00:08, 339.34it/s]
# Generating filters:  50%|████▉     | 2996/6000 [00:08<00:08, 339.38it/s]
# Generating filters:  51%|█████     | 3031/6000 [00:08<00:08, 340.10it/s]
# Generating filters:  51%|█████     | 3066/6000 [00:08<00:08, 340.99it/s]
# Generating filters:  52%|█████▏    | 3101/6000 [00:09<00:08, 341.31it/s]
# Generating filters:  52%|█████▏    | 3136/6000 [00:09<00:08, 341.52it/s]
# Generating filters:  53%|█████▎    | 3171/6000 [00:09<00:08, 340.70it/s]
# Generating filters:  53%|█████▎    | 3206/6000 [00:09<00:08, 340.85it/s]
# Generating filters:  54%|█████▍    | 3241/6000 [00:09<00:08, 337.48it/s]
# Generating filters:  55%|█████▍    | 3275/6000 [00:09<00:08, 332.21it/s]
# Generating filters:  55%|█████▌    | 3309/6000 [00:09<00:08, 333.24it/s]
# Generating filters:  56%|█████▌    | 3344/6000 [00:09<00:07, 335.55it/s]
# Generating filters:  56%|█████▋    | 3379/6000 [00:09<00:07, 337.17it/s]
# Generating filters:  57%|█████▋    | 3414/6000 [00:09<00:07, 339.09it/s]
# Generating filters:  57%|█████▊    | 3450/6000 [00:10<00:07, 343.05it/s]
# Generating filters:  58%|█████▊    | 3485/6000 [00:10<00:07, 344.88it/s]
# Generating filters:  59%|█████▊    | 3521/6000 [00:10<00:07, 348.63it/s]
# Generating filters:  59%|█████▉    | 3558/6000 [00:10<00:06, 352.34it/s]
# Generating filters:  60%|█████▉    | 3595/6000 [00:10<00:06, 354.74it/s]
# Generating filters:  61%|██████    | 3632/6000 [00:10<00:06, 356.79it/s]
# Generating filters:  61%|██████    | 3669/6000 [00:10<00:06, 358.31it/s]
# Generating filters:  62%|██████▏   | 3705/6000 [00:10<00:06, 358.17it/s]
# Generating filters:  62%|██████▏   | 3741/6000 [00:10<00:06, 351.68it/s]
# Generating filters:  63%|██████▎   | 3777/6000 [00:10<00:06, 344.83it/s]
# Generating filters:  64%|██████▎   | 3812/6000 [00:11<00:06, 340.28it/s]
# Generating filters:  64%|██████▍   | 3847/6000 [00:11<00:06, 337.40it/s]
# Generating filters:  65%|██████▍   | 3881/6000 [00:11<00:06, 335.11it/s]
# Generating filters:  65%|██████▌   | 3915/6000 [00:11<00:06, 333.62it/s]
# Generating filters:  66%|██████▌   | 3949/6000 [00:11<00:06, 335.11it/s]
# Generating filters:  66%|██████▋   | 3984/6000 [00:11<00:05, 336.61it/s]
# Generating filters:  67%|██████▋   | 4018/6000 [00:11<00:05, 336.72it/s]
# Generating filters:  68%|██████▊   | 4052/6000 [00:11<00:05, 336.28it/s]
# Generating filters:  68%|██████▊   | 4087/6000 [00:11<00:05, 338.71it/s]
# Generating filters:  69%|██████▊   | 4123/6000 [00:11<00:05, 344.15it/s]
# Generating filters:  69%|██████▉   | 4159/6000 [00:12<00:05, 347.71it/s]
# Generating filters:  70%|██████▉   | 4195/6000 [00:12<00:05, 350.34it/s]
# Generating filters:  71%|███████   | 4231/6000 [00:12<00:05, 349.23it/s]
# Generating filters:  71%|███████   | 4266/6000 [00:12<00:05, 346.21it/s]
# Generating filters:  72%|███████▏  | 4301/6000 [00:12<00:04, 342.71it/s]
# Generating filters:  72%|███████▏  | 4336/6000 [00:12<00:04, 340.80it/s]
# Generating filters:  73%|███████▎  | 4371/6000 [00:12<00:04, 339.31it/s]
# Generating filters:  73%|███████▎  | 4406/6000 [00:12<00:04, 340.25it/s]
# Generating filters:  74%|███████▍  | 4441/6000 [00:12<00:04, 340.79it/s]
# Generating filters:  75%|███████▍  | 4477/6000 [00:13<00:04, 344.35it/s]
# Generating filters:  75%|███████▌  | 4512/6000 [00:13<00:04, 342.77it/s]
# Generating filters:  76%|███████▌  | 4547/6000 [00:13<00:04, 341.58it/s]
# Generating filters:  76%|███████▋  | 4582/6000 [00:13<00:04, 340.23it/s]
# Generating filters:  77%|███████▋  | 4617/6000 [00:13<00:04, 339.90it/s]
# Generating filters:  78%|███████▊  | 4651/6000 [00:13<00:04, 336.92it/s]
# Generating filters:  78%|███████▊  | 4685/6000 [00:13<00:03, 337.04it/s]
# Generating filters:  79%|███████▊  | 4719/6000 [00:13<00:03, 336.66it/s]
# Generating filters:  79%|███████▉  | 4753/6000 [00:13<00:03, 334.58it/s]
# Generating filters:  80%|███████▉  | 4787/6000 [00:13<00:03, 333.71it/s]
# Generating filters:  80%|████████  | 4821/6000 [00:14<00:03, 333.28it/s]
# Generating filters:  81%|████████  | 4855/6000 [00:14<00:03, 333.19it/s]
# Generating filters:  81%|████████▏ | 4889/6000 [00:14<00:03, 333.63it/s]
# Generating filters:  82%|████████▏ | 4924/6000 [00:14<00:03, 335.79it/s]
# Generating filters:  83%|████████▎ | 4959/6000 [00:14<00:03, 339.10it/s]
# Generating filters:  83%|████████▎ | 4994/6000 [00:14<00:02, 342.09it/s]
# Generating filters:  84%|████████▍ | 5030/6000 [00:14<00:02, 346.18it/s]
# Generating filters:  84%|████████▍ | 5067/6000 [00:14<00:02, 350.17it/s]
# Generating filters:  85%|████████▌ | 5103/6000 [00:14<00:02, 349.12it/s]
# Generating filters:  86%|████████▌ | 5139/6000 [00:14<00:02, 351.80it/s]
# Generating filters:  86%|████████▋ | 5176/6000 [00:15<00:02, 354.35it/s]
# Generating filters:  87%|████████▋ | 5212/6000 [00:15<00:02, 352.76it/s]
# Generating filters:  87%|████████▋ | 5248/6000 [00:15<00:02, 348.62it/s]
# Generating filters:  88%|████████▊ | 5283/6000 [00:15<00:02, 344.23it/s]
# Generating filters:  89%|████████▊ | 5318/6000 [00:15<00:01, 341.02it/s]
# Generating filters:  89%|████████▉ | 5353/6000 [00:15<00:01, 338.79it/s]
# Generating filters:  90%|████████▉ | 5387/6000 [00:15<00:01, 336.81it/s]
# Generating filters:  90%|█████████ | 5421/6000 [00:15<00:01, 336.11it/s]
# Generating filters:  91%|█████████ | 5455/6000 [00:15<00:01, 332.40it/s]
# Generating filters:  91%|█████████▏| 5489/6000 [00:15<00:01, 334.34it/s]
# Generating filters:  92%|█████████▏| 5523/6000 [00:16<00:01, 335.85it/s]
# Generating filters:  93%|█████████▎| 5557/6000 [00:16<00:01, 336.71it/s]
# Generating filters:  93%|█████████▎| 5591/6000 [00:16<00:01, 337.69it/s]
# Generating filters:  94%|█████████▍| 5625/6000 [00:16<00:01, 337.88it/s]
# Generating filters:  94%|█████████▍| 5660/6000 [00:16<00:01, 339.80it/s]
# Generating filters:  95%|█████████▍| 5694/6000 [00:16<00:00, 339.42it/s]
# Generating filters:  95%|█████████▌| 5729/6000 [00:16<00:00, 339.88it/s]
# Generating filters:  96%|█████████▌| 5764/6000 [00:16<00:00, 340.83it/s]
# Generating filters:  97%|█████████▋| 5800/6000 [00:16<00:00, 346.22it/s]
# Generating filters:  97%|█████████▋| 5835/6000 [00:17<00:00, 345.35it/s]
# Generating filters:  98%|█████████▊| 5870/6000 [00:17<00:00, 343.76it/s]
# Generating filters:  98%|█████████▊| 5905/6000 [00:17<00:00, 342.20it/s]
# Generating filters:  99%|█████████▉| 5940/6000 [00:17<00:00, 342.50it/s]
# Generating filters: 100%|█████████▉| 5975/6000 [00:17<00:00, 341.70it/s]
# Generating filters: 100%|██████████| 6000/6000 [00:17<00:00, 343.15it/s]

# %% [markdown]
# ## Explaining one instance
# Producing saliency maps for top $k$ predicted classes.

# %%
def example(img, top_k=3):
    saliency = explainer(img.cuda()).cpu().numpy()
    p, c = torch.topk(model(img.cuda()), k=top_k)
    p, c = p[0], c[0]
    
    plt.figure(figsize=(10, 5*top_k))
    for k in range(top_k):
        plt.subplot(top_k, 2, 2*k+1)
        plt.axis('off')
        plt.title('{:.2f}% {}'.format(100*p[k], get_class_name(c[k])))
        tensor_imshow(img[0])

        plt.subplot(top_k, 2, 2*k+2)
        plt.axis('off')
        plt.title(get_class_name(c[k]))
        tensor_imshow(img[0])
        sal = saliency[c[k]]
        plt.imshow(sal, cmap='jet', alpha=0.5)
        plt.colorbar(fraction=0.046, pad=0.04)

    plt.show()

# %%
example(read_tensor('/work/lisabdunlap/explain-eval/data/ILSVRC2012_img_val/ILSVRC2012_val_00000001.JPEG'), 3)

# %% [markdown]
# ## Explaining all images in dataloader
# Explaining the top predicted class for each image.

# %%
def explain_all(data_loader, explainer):
    # Get all predicted labels first
    target = np.empty(len(data_loader), np.int)
    for i, (img, _) in enumerate(tqdm(data_loader, total=len(data_loader), desc='Predicting labels')):
        p, c = torch.max(model(img.cuda()), dim=1)
        target[i] = c[0]

    # Get saliency maps for all images in val loader
    explanations = np.empty((len(data_loader), *args.input_size))
    for i, (img, _) in enumerate(tqdm(data_loader, total=len(data_loader), desc='Explaining images')):
        saliency_maps = explainer(img.cuda())
        explanations[i] = saliency_maps[target[i]].cpu().numpy()
    return explanations

# %%
explanations = explain_all(data_loader, explainer)

# Save explanations if needed.
# explanations.tofile('exp_{:05}-{:05}.npy'.format(args.range[0], args.range[-1]))
# Out:
# Predicting labels:   0%|          | 0/10 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-6b6bf05bffec> in <module>
# ----> 1 explanations = explain_all(data_loader, explainer)
#       2
#       3 # Save explanations if needed.
#       4 # explanations.tofile('exp_{:05}-{:05}.npy'.format(args.range[0], args.range[-1]))
#
# <ipython-input-18-722523180524> in explain_all(data_loader, explainer)
#       2     # Get all predicted labels first
#       3     target = np.empty(len(data_loader), np.int)
# ----> 4     for i, (img, _) in enumerate(tqdm(data_loader, total=len(data_loader), desc='Predicting labels')):
#       5         p, c = torch.max(model(img.cuda()), dim=1)
#       6         target[i] = c[0]
#
# /work/lisabdunlap/anaconda3/lib/python3.7/site-packages/tqdm/_tqdm.py in __iter__(self)
#    1020                 """), fp_write=getattr(self.fp, 'write', sys.stderr.write))
#    1021
# -> 1022             for obj in iterable:
#    1023                 yield obj
#    1024                 # Update and possibly print the progressbar.
#
# /work/lisabdunlap/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     817             else:
#     818                 del self._task_info[idx]
# --> 819                 return self._process_data(data)
#     820
#     821     next = __next__  # Python 2 compatibility
#
# /work/lisabdunlap/anaconda3/lib/python3.7/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#     844         self._try_put_index()
#     845         if isinstance(data, ExceptionWrapper):
# --> 846             data.reraise()
#     847         return data
#     848
#
# /work/lisabdunlap/anaconda3/lib/python3.7/site-packages/torch/_utils.py in reraise(self)
#     383             # (https://bugs.python.org/issue2651), so we work around it.
#     384             msg = KeyErrorMessage(msg)
# --> 385         raise self.exc_type(msg)
#
# IndexError: Caught IndexError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/work/lisabdunlap/anaconda3/lib/python3.7/site-packages/torch/utils/data/_utils/worker.py", line 178, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/work/lisabdunlap/anaconda3/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/work/lisabdunlap/anaconda3/lib/python3.7/site-packages/torch/utils/data/_utils/fetch.py", line 44, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/work/lisabdunlap/anaconda3/lib/python3.7/site-packages/torchvision/datasets/folder.py", line 137, in __getitem__
#     path, target = self.samples[index]
# IndexError: list index out of range

# %%
for i, (img, _) in enumerate(data_loader):
    p, c = torch.max(model(img.cuda()), dim=1)
    p, c = p[0].item(), c[0].item()
    
    plt.figure(figsize=(10, 5))
    plt.subplot(121)
    plt.axis('off')
    plt.title('{:.2f}% {}'.format(100*p, get_class_name(c)))
    tensor_imshow(img[0])
    
    plt.subplot(122)
    plt.axis('off')
    plt.title(get_class_name(c))
    tensor_imshow(img[0])
    sal = explanations[i]
    cv2.imwrite('/work/lisabdunlap/explain-eval/results/pls_rise_work/')
    plt.imshow(sal, cmap='jet', alpha=0.5)
    #plt.colorbar(fraction=0.046, pad=0.04)
    
    plt.show()
